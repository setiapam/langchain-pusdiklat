# %%
# Memuat API key dari file .env
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Menggunakan pre-built agent dari LangChain untuk menggunakan tools eksternal
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_tavily import TavilySearch
from pprint import pprint

# Memuat tool pencarian Tavily menggunakan paket integrasi mandiri yang direkomendasikan
tools = [TavilySearch(max_results=5)]

# Membuat instance agent dengan model LLM dan daftar tools yang tersedia
agent = create_agent(tools=tools, model="google_genai:gemini-3.1-flash-lite")

# Menyusun pertanyaan pengguna tentang final Piala Dunia FIFA 2026
question = HumanMessage(content="Tim pada Final Piala Dunia FIFA 2026?")

# Memanggil agent untuk menjawab pertanyaan
# Agent akan menggunakan tool TavilySearch untuk mencari hasil terbaru di internet
response = agent.invoke(
    {"messages": [question]}
)

pprint(response['messages'][-1].content)
# Out:
# [{'extras': {'signature': 'EjQKMgERTTIPBo38jvAM9+Oihw7HpooUw58OyV2V/WEZ5n852yzRAZCQgRT0R31QpmwsEhYn'},
#   'text': 'Piala Dunia FIFA 2026 saat ini sedang berlangsung atau telah '
#           'mencapai babak final (berdasarkan informasi terkini dalam konteks '
#           'simulasi/data yang tersedia), dan pertandingan final dijadwalkan '
#           'mempertemukan **Argentina** melawan **Spanyol**.\n'
#           '\n'
#           'Pertandingan final tersebut direncanakan berlangsung di Stadion '
#           'MetLife di East Rutherford, New Jersey, Amerika Serikat.',
#   'type': 'text'}]

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# Membuat instance agent dengan model LLM tanpa mendaftarkan tools
agent = create_agent(model="google_genai:gemini-3.1-flash-lite")

# Menyusun pertanyaan pengguna
question = HumanMessage(content="kapan batasan data yang kamu pakai untuk training?")

# Memanggil agent untuk menjawab pertanyaan
# Agent akan menjawab langsung karena tidak ada tools yang didaftarkan
response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# [{'type': 'text', 'text': 'Data pelatihan yang saya gunakan memiliki batasan waktu (knowledge cutoff) hingga **Januari 2025**.\n\nArtinya, saya memiliki pengetahuan tentang peristiwa, perkembangan teknologi, dan informasi yang terjadi hingga bulan tersebut. Informasi atau peristiwa yang terjadi setelah Januari 2025 mungkin tidak saya ketahui, kecuali jika saya mengakses informasi secara langsung melalui alat pencarian (browsing) yang terintegrasi.', 'extras': {'signature': 'EjQKMgERTTIPtAh4xhaitdyrQ0xwcHYas8a7kVbHHT/QDMx5LWlhc0ZZht5CcDcHY5dN4XGT'}}]

# %%
# Menyusun pertanyaan pengguna
question = HumanMessage(content="Ada berapa tim yang berlaga di piala dunia 2026?")

# Memanggil agent untuk menjawab pertanyaan
# Agent akan menjawab langsung karena tidak ada tools yang didaftarkan
response = agent.invoke(
    {"messages": [question]}
)

pprint(response['messages'][-1].content)
# Out:
# [{'extras': {'signature': 'EjQKMgERTTIPWpq4KQ8ApibJH7zmkLXJPY+QpkUNDbNpxToC5i3/hjRvbggQ1l+t4wXcTkQa'},
#   'text': 'Piala Dunia 2026 akan diikuti oleh **48 tim**.\n'
#           '\n'
#           'Ini merupakan perubahan format dari edisi-edisi sebelumnya yang '
#           'biasanya diikuti oleh 32 tim. Piala Dunia 2026 yang diselenggarakan '
#           'di Amerika Serikat, Kanada, dan Meksiko ini akan menjadi turnamen '
#           'pertama dalam sejarah yang menggunakan format 48 peserta.',
#   'type': 'text'}]
